# %%
import torch

# Thêm chữ r ở trước dấu nháy và sửa thành model.pth
model_data = torch.load(r'D:\UIT\Data Mining\x-mir\model.pth', map_location='cpu')

# Thêm chữ r ở trước dấu nháy cho file đích
torch.save(model_data, r'D:\UIT\Data Mining\x-mir\model.pt')

print("Chuyển đổi thành công!")
# Out:
# Chuyển đổi thành công!
